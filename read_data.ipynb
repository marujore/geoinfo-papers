# %%
from pathlib import Path

import pandas as pd
import numpy as np

# %%
geoinfo_dir = Path('./2021')

# %%
artigos = pd.read_csv(
    geoinfo_dir / 'artigos.csv',
    quotechar='"',
    quoting=1,
    encoding='utf-8-sig'
)
print(f"Artigos: {len(artigos)} registros")

pessoas = pd.read_csv(
    geoinfo_dir / 'pessoas.csv',
    quotechar='"',
    quoting=1,
    encoding='utf-8-sig'
)
print(f"Pessoas: {len(pessoas)} registros")

autoria = pd.read_csv(
    geoinfo_dir / 'autoria.csv',
    quotechar='"',
    quoting=1,
    encoding='utf-8-sig'
)
print(f"Autoria: {len(autoria)} registros")

comite = pd.read_csv(
    geoinfo_dir / 'comite_cientifico.csv',
    quotechar='"',
    quoting=1,
    encoding='utf-8-sig'
)
print(f"Comitê: {len(comite)} registros")

organizacao = pd.read_csv(
    geoinfo_dir / 'organizacao.csv',
    quotechar='"',
    quoting=1,
    encoding='utf-8-sig'
)
print(f"Organização: {len(organizacao)} registros")

evento = pd.read_csv(
    geoinfo_dir / 'evento.csv',
    quotechar='"',
    quoting=1,
    encoding='utf-8-sig'
)
print(f"Evento: {len(evento)} registros")
# Out:
# Artigos: 29 registros
# Pessoas: 168 registros
# Autoria: 121 registros
# Comitê: 61 registros
# Organização: 2 registros
# Evento: 1 registros

# %%
artigos.head()
# Out:
#    id_artigo                                             titulo  \
# 0          1  Monitoring the spatiotemporal dynamics of surf...
# 1          2  Towards an analytical and operational trajecto...
# 2          3  Mapping irrigated rice using MSI/Sentinel-2 ti...
# 3          4  Study on changing trends in climatic extremes ...
# 4          5  Effects of landscape fragmentation in the Prot...
#
#                                             abstract  n_paginas tipo_artigo  \
# 0  Water stored in dams and reservoirs is essenti...         15        full
# 1  In recent years, many research works involving...         12        full
# 2  The State of Rio Grande do Sul is the largest ...          9        full
# 3  It is noticeable that the climate trends are c...         12        full
# 4  Tropical forest remnants play an important rol...         11        full
#
#     lingua  n_edicao
# 0  english        22
# 1  english        22
# 2  english        22
# 3  english        22
# 4  english        22

# %%
pessoas.head()
# Out:
#    id_pessoa                           nome  \
# 0          1        Bello Abubakar Abubakar
# 1          2         Sani Abubakar Abubakar
# 2          3      Damião Ribeiro de Almeida
# 3          4   Aillkeen Bezerra de Oliveira
# 4          5  Samuel Pereira de Vasconcelos
#
#                                      instituicao
# 0                       Nigerian Defence Academy
# 1                             Kaduna Polytechnic
# 2  Universidade Federal de Campina Grande (UFCG)
# 3  Universidade Federal de Campina Grande (UFCG)
# 4  Universidade Federal de Campina Grande (UFCG)

# %%
autoria.head()
# Out:
#    id_autoria  id_artigo  id_pessoa  ordem_autoria  autor_correspondente
# 0           1          1        1.0              1                 False
# 1           2          1        2.0              2                 False
# 2           3          2        3.0              1                 False
# 3           4          2        4.0              2                 False
# 4           5          2        5.0              3                 False

# %%
comite.head()
# Out:
#    id_revisor  id_pessoa  n_edicao
# 0           1        111        22
# 1           2        110        22
# 2           3        112        22
# 3           4        113        22
# 4           5        114        22

# %%
organizacao.head()
# Out:
#    id_organizador  id_pessoa         funcao  n_edicao
# 0               1        111  Program Chair        22
# 1               2        110  General Chair        22

# %%
evento.head()
# Out:
#    id_evento  n_edicao   ano                local
# 0          1        22  2021  São José dos Campos

# %%
#DF Papers
df = artigos.merge(autoria, on='id_artigo')
df = df.merge(pessoas[['id_pessoa', 'nome', 'instituicao']], on='id_pessoa')

df_papers = df.groupby('id_artigo').agg({
    'titulo': 'first',
    'abstract': 'first',
    'tipo_artigo': 'first',
    'lingua': 'first',
    'n_edicao': 'first',
    'nome': list,
    'instituicao': list
}).reset_index()
df_papers
# Out:
#     id_artigo                                             titulo  \
# 0           1  Monitoring the spatiotemporal dynamics of surf...
# 1           2  Towards an analytical and operational trajecto...
# 2           3  Mapping irrigated rice using MSI/Sentinel-2 ti...
# 3           4  Study on changing trends in climatic extremes ...
# 4           5  Effects of landscape fragmentation in the Prot...
# 5           6  TopoGeo: a data model for elaboration of cadas...
# 6           7  Anomaly detection based method for spatio-temp...
# 7           8  Spatial data handling in NoSQL databases: a us...
# 8           9  SAFmaps: the WebGIS for sustainability assessm...
# 9          10  A framework for the generation of the rainwate...
# 10         11  Classification of the water volume of dams usi...
# 11         12  Shalstab and TRIGRS: comparison of two models ...
# 12         13  Detection of spikes in single-beam bathymetry ...
# 13         14  Lightning-induced wildfire in Serra do Cipó Na...
# 14         15  Evaluating a self-organizing map approach to c...
# 15         16  Characterization of center pivot irrigation sy...
# 16         17  Description of land cover and susceptibility t...
# 17         18  A method for generating and sharing 3D sanitat...
# 18         19  Estrutura urbana na Amazônia paraense a partir...
# 19         20  'Do Pasto ao Prato': a citizen science initiat...
# 20         21  Comparaçăo da componente vertical GNSS determi...
# 21         22  Análise da concordância entre dados de degrada...
# 22         23    IBGE Statistical Grid in Compact Representation
# 23         24  Automated cloud coverage analysis with Brazil ...
# 24         25  Análise das condiçőes ambientais na Serra do C...
# 25         26  Utilizando o padrão SpatioTemporal Asset Catal...
# 26         27  Gerenciamento de dados geográficos no Projeto ...
# 27         28  Occurrence of marine heatwaves along the north...
# 28         29  A meta-classifier approach for outlier identif...
#
#                                              abstract tipo_artigo      lingua  \
# 0   Water stored in dams and reservoirs is essenti...        full     english
# 1   In recent years, many research works involving...        full     english
# 2   The State of Rio Grande do Sul is the largest ...        full     english
# 3   It is noticeable that the climate trends are c...        full     english
# 4   Tropical forest remnants play an important rol...        full     english
# 5   The deed description and the survey plan prope...        full     english
# 6   Remote Sensing technologies and Machine Learni...        full     english
# 7   Spatial data handling is a core aspect in seve...        full     english
# 8   This paper presents the SAFmaps, an open-acces...        full     english
# 9   Urbanization in Brazilian cities often occurs ...        full     english
# 10  Deep Convolutional Neural Networks (DCNN) have...        full     english
# 11  Landslides are natural phenomena occurring wor...        full     english
# 12  The process of detecting spurious depth (spike...        full     english
# 13  Analysis was performed to search all CG lightn...        full     english
# 14  Brazil has a substantial diversity of agricult...        full     english
# 15  This study purposes identify the changes in ce...        full     english
# 16  The environmental issues, like burn events and...        full     english
# 17  The three-dimensional representation of realit...        full     english
# 18  At the interface between concept and measureme...       short  portuguese
# 19  Livestock farming in Brazil is linked to negat...       short     english
# 20  The improvement of the Global Navigation Satel...       short  portuguese
# 21  The characterization of forest degradation is ...       short  portuguese
# 22  This article describes the development of the ...       short     english
# 23  This paper approaches the topic of Data Cubes ...       short     english
# 24  This work analyzed data of precipitation, days...       short  portuguese
# 25  The Brazil Data Cube project (BDC) is an initi...       short  portuguese
# 26  The Brumadinho UFMG Platform was designed for ...       short  portuguese
# 27  Marine Heatwaves (MHWs) are defined as high-im...       short     english
# 28  Geodetic networks provide the positional basis...       short     english
#
#     n_edicao                                               nome  \
# 0         22  [Bello Abubakar Abubakar, Sani Abubakar Abubakar]
# 1         22  [Damião Ribeiro de Almeida, Aillkeen Bezerra d...
# 2         22  [Juliana de Abreu Araújo, Allan Henrique Lima ...
# 3         22  [Filipe Junio S. Coelho, Marconi de Arruda Per...
# 4         22  [Igor José Malfetoni Ferreira, Debora Cristina...
# 5         22  [Leandro L. S. França, Julierne Pinheiro, Joel...
# 6         22  [Vinícius L. S. Gino, Rogério G. Negri, Felipe...
# 7         22  [Heron Carlos Gonçalves, Anderson Chaves Carniel]
# 8         22  [Marjorie M. Guarenghi, João Luís Santos, Arna...
# 9         22  [Pedro Vitor Duarte Guimarães, Marconi de Arru...
# 10        22  [Mateus de Souza Miranda, Renato de Sousa Maxi...
# 11        22  [Téhrrie Caroline Konig Ferraz Pacheco, Herman...
# 12        22  [Karine Pinheiro, Gabriela Gouveia Lana, Laura...
# 13        22         [Vanúcia Schumacher, Marco Aurélio Barros]
# 14        22  [Marcos A. S. da Silva, Leonardo N. Matos, Flá...
# 15        22  [Philipe Souza Siműes, Marionei Fomaca de Sous...
# 16        22  [Felipe N. Souza, Rogério G. Negri, Vinícius L...
# 17        22  [Kauê de Moraes Vestena, Nathan Damas Antonio,...
# 18        22  [Julia Corrêa Côrtes, José Diego Gobbo Alves, ...
# 19        22  [Erasmus zu Ermgassen, Vivian Ribeiro, Patrick...
# 20        22  [Samoel Giehl, Regiane Dalazoana, Túlio Alves ...
# 21        22  [Aline Daniele Jacon, Maria Isabel Sobral Esca...
# 22        22  [Peter Krauss, Luis Felipe Bortolatto da Cunha...
# 23        22  [Thainara Munhoz Alexandre de Lima, Romulo Mar...
# 24        22  [Gilberto Ribeiro de Queiroz, Guilherme Martin...
# 25        22  [Mateus de Souza Macul, Paulo W. Pinto da Cunh...
# 26        22  [Bruno dos Santos, Gilberto Eidi Teramoto Oliv...
# 27        22        [Ingrid L. Santana, Michele Brito Pinheiro]
# 28        22  [Luci A. Nicolau, Gabriel Lucas Xavier da Silv...
#
#                                           instituicao
# 0      [Nigerian Defence Academy, Kaduna Polytechnic]
# 1   [Universidade Federal de Campina Grande (UFCG)...
# 2   [Instituto Nacional de Pesquisas Espaciais (IN...
# 3   [Universidade Federal de São João Del Rei (UFS...
# 4   [Instituto Nacional de Pesquisas Espaciais (IN...
# 5   [Universidade Federal de Pernambuco (UFPE), Mi...
# 6   [Universidade Estadual Paulista (UNESP), Unive...
# 7   [Universidade Tecnológica Federal do Paraná (U...
# 8   [Universidade Estadual de Campinas (UNICAMP), ...
# 9   [Universidade Federal de São João Del Rei (UFS...
# 10  [Instituto Nacional de Pesquisas Espaciais (IN...
# 11  [Instituto Nacional de Pesquisas Espaciais (IN...
# 12  [Universidade Federal de Viçosa (UFV), Univers...
# 13  [Instituto Nacional de Pesquisas Espaciais (IN...
# 14  [Embrapa Tabuleiros Costeiros, Universidade Fe...
# 15  [Instituto Nacional de Pesquisas Espaciais (IN...
# 16  [Universidade Estadual Paulista (UNESP), Unive...
# 17  [Universidade Federal do Paraná (UFPR), Univer...
# 18  [Universidade Estadual de Campinas (UNICAMP), ...
# 19  [UCLouvain, Stockholm Environment Institute, U...
# 20  [Universidade Federal do Paraná (UFPR), Univer...
# 21  [Instituto Nacional de Pesquisas Espaciais (IN...
# 22  [Instituto de Tecnologias Geo-Sociais AddressF...
# 23  [Instituto Nacional de Pesquisas Espaciais (IN...
# 24  [Instituto Nacional de Pesquisas Espaciais (IN...
# 25  [Instituto Nacional de Pesquisas Espaciais (IN...
# 26  [Instituto Nacional de Pesquisas Espaciais (IN...
# 27  [Universidade Federal de Minas Gerais (UFMG), ...
# 28  [Universidade Federal de Minas Gerais (UFMG), ...

# %%
#DF Comitê
df_comite = comite.merge(pessoas, on='id_pessoa')
df_comite = df_comite[['id_pessoa', 'nome', 'instituicao', 'n_edicao']]
df_comite = df_comite.sort_values('nome').reset_index(drop=True)
df_comite
# Out:
#     id_pessoa                   nome  \
# 0         116     A. Miguel Monteiro
# 1         111  Alan J. Salomão Graça
# 2         112          Alber Sànchez
# 3         113    Alessandra Palmeiro
# 4         114        Ana Clara Moura
# ..        ...                    ...
# 56        164          Sonaira Silva
# 57        166        Tatiana Kuplich
# 58        165        Thales Köorting
# 59        167         Tiago Carneiro
# 60        168       Vivian Fernandes
#
#                                        instituicao  n_edicao
# 0                                             INPE        22
# 1   Universidade Estadual do Rio de Janeiro (UERJ)        22
# 2                                             INPE        22
# 3                                             UFRJ        22
# 4                                             UFMG        22
# ..                                             ...       ...
# 56                                            UFAC        22
# 57                                            INPE        22
# 58                                            INPE        22
# 59                                            UFOP        22
# 60                                            UFBA        22
#
# [61 rows x 4 columns]
